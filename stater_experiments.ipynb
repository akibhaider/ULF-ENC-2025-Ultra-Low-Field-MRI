# %%
# !pip install nilearn nibabel matplotlib pandas itk itkwidgets gdown
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 20.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 MB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 MB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.0/28.0 MB 50.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 MB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.5/28.5 MB 43.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 48.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 53.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.6/271.6 kB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.7/515.7 kB 21.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 52.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 53.6 MB/s eta 0:00:00
# ...

# %%
# !pip install SimpleITK scikit-image opencv-python Pillow torchvision tensorflow scipy opencv-python-headless
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 79.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 56.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install --upgrade "nilearn[all]"
# Out:
# ...
# WARNING: nilearn 0.11.1 does not provide the extra 'all'
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Copying contents of folder

# %%
# !rsync -av --progress "/content/drive/MyDrive/Training data/" "/content/Training_Data/"
# Out:
# sending incremental file list
# created directory /content/Training_Data
# ./
# POCEMR001/
# POCEMR001/3T/
# POCEMR001/3T/POCEMR001_FLAIR.nii.gz
#       4,684,170 100%   20.07MB/s    0:00:00 (xfr#1, to-chk=397/451)
# POCEMR001/3T/POCEMR001_T1.nii.gz
#       4,536,718 100%    4.52MB/s    0:00:00 (xfr#2, to-chk=396/451)
# POCEMR001/3T/POCEMR001_T2.nii.gz
#       4,688,531 100%    2.97MB/s    0:00:01 (xfr#3, to-chk=395/451)
# POCEMR001/64mT/
# POCEMR001/64mT/POCEMR001_FLAIR.nii.gz
#       4,481,072 100%    6.86MB/s    0:00:00 (xfr#4, to-chk=394/451)
# POCEMR001/64mT/POCEMR001_T1.nii.gz
#       4,506,721 100%    2.83MB/s    0:00:01 (xfr#5, to-chk=393/451)
# POCEMR001/64mT/POCEMR001_T2.nii.gz
#       4,145,472 100%    8.00MB/s    0:00:00 (xfr#6, to-chk=392/451)
# POCEMR003/
# POCEMR003/3T/
# POCEMR003/3T/POCEMR003_FLAIR.nii.gz
#       4,154,525 100%    4.98MB/s    0:00:00 (xfr#7, to-chk=389/451)
# POCEMR003/3T/POCEMR003_T1.nii.gz
# ...

# %%
import numpy as mp
import nibabel as nib
import itk
import itkwidgets
from ipywidgets import interact, interactive, IntSlider, ToggleButtons
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
# Load the NIfTI file
img_1_3t_F = nib.load('/content/Training_Data/POCEMR001/3T/POCEMR001_FLAIR.nii.gz')
img_1_mt_F = nib.load('/content/Training_Data/POCEMR001/64mT/POCEMR001_FLAIR.nii.gz')

# %%
# Get the header
header_1_3t_F = img_1_3t_F.header

# Print all header fields (as a dictionary)
# print(header)

# Access specific metadata
# print("Image shape:", header.get_data_shape())   # Dimensions (224, 224, 160))
# print("Voxel sizes (mm):", header.get_zooms())   # Resolution ((1.0, 1.0, 1.0) mm)
# print("Data type:", header.get_data_dtype())     # uint8
print("Affine matrix:\n", img_1_3t_F.affine)            # Spatial orientation
# Out:
# Affine matrix:
#  [[ 1.00000000e+00 -4.89699991e-12  0.00000000e+00 -1.08574501e+02]
#  [ 4.86100006e-12  9.99194384e-01 -4.01317962e-02 -8.88353119e+01]
#  [ 9.85000059e-13  4.01317887e-02  9.99194443e-01 -4.94724426e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]

# %%
data_1_3t_F = img_1_3t_F.get_fdata()
data_1_mt_F = img_1_mt_F.get_fdata()

# %%
# Plot axial-slice (XY-plane)
fig, axial = plt.subplots(1, 5, figsize=(10, 5))
axial[0].imshow(data_1_3t_F[:, :, 79], cmap='gray')
axial[1].imshow(data_1_3t_F[:, :, 80], cmap='gray')
axial[2].imshow(data_1_3t_F[:, :, 81], cmap='gray')
axial[3].imshow(data_1_3t_F[:, :, 82], cmap='gray')
axial[4].imshow(data_1_3t_F[:, :, 83], cmap='gray')

# %%
data_1_mt_F = img_1_mt_F.get_fdata()

# Plot axial-slice (XY-plane)
fig, axial = plt.subplots(1, 5, figsize=(10, 5))
axial[0].imshow(data_1_mt_F[:, :, 79], cmap='gray')
axial[1].imshow(data_1_mt_F[:, :, 80], cmap='gray')
axial[2].imshow(data_1_mt_F[:, :, 81], cmap='gray')
axial[3].imshow(data_1_mt_F[:, :, 82], cmap='gray')
axial[4].imshow(data_1_mt_F[:, :, 83], cmap='gray')

# %%
# Plot coronal-slice (XZ-plane)
fig, cor = plt.subplots(1, 5, figsize=(10, 5))
cor[0].imshow(data_1_3t_F[:, 79, :], cmap='gray')
cor[1].imshow(data_1_3t_F[:, 80, :], cmap='gray')
cor[2].imshow(data_1_3t_F[:, 81, :], cmap='gray')
cor[3].imshow(data_1_3t_F[:, 82, :], cmap='gray')
cor[4].imshow(data_1_3t_F[:, 83, :], cmap='gray')

# %%
# Plot coronal-slice (XZ-plane)
fig, cor = plt.subplots(1, 5, figsize=(10, 5))
cor[0].imshow(data_1_mt_F[:, 79, :], cmap='gray')
cor[1].imshow(data_1_mt_F[:, 80, :], cmap='gray')
cor[2].imshow(data_1_mt_F[:, 81, :], cmap='gray')
cor[3].imshow(data_1_mt_F[:, 82, :], cmap='gray')
cor[4].imshow(data_1_mt_F[:, 83, :], cmap='gray')

# %%
# Plot sagittal-slice (YZ-plane)
fig, sag = plt.subplots(1, 5, figsize=(10, 5))
sag[0].imshow(data_1_3t_F[79, :, :], cmap='gray')
sag[1].imshow(data_1_3t_F[80, :, :], cmap='gray')
sag[2].imshow(data_1_3t_F[81, :, :], cmap='gray')
sag[3].imshow(data_1_3t_F[82, :, :], cmap='gray')
sag[4].imshow(data_1_3t_F[83, :, :], cmap='gray')

# %%
# Plot sagittal-slice (YZ-plane)
fig, sag = plt.subplots(1, 5, figsize=(10, 5))
sag[0].imshow(data_1_mt_F[79, :, :], cmap='gray')
sag[1].imshow(data_1_mt_F[80, :, :], cmap='gray')
sag[2].imshow(data_1_mt_F[81, :, :], cmap='gray')
sag[3].imshow(data_1_mt_F[82, :, :], cmap='gray')
sag[4].imshow(data_1_mt_F[83, :, :], cmap='gray')
